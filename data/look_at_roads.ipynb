# %% [markdown]
# steps:
# 1. load map nets to network
# 2. graph conected components
# 3. qury is x in our net

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
paths = pd.read_csv(r'Railroads.csv')
paths.head()
# Out:
#        from               to  length   color
# 0   Calgary          Seattle       4    gray
# 1    Helena          Seattle       6  yellow
# 2  Portland   Salt Lake City       6    blue
# 3  Montreal  Sault St. Marie       5   black
# 4   Chicago       Pittsburgh       3  orange

# %%
paths_graph = nx.from_pandas_edgelist(paths,source='from',target='to')

# %%
type(paths_graph)
# Out:
# networkx.classes.graph.Graph

# %%
dir(paths_graph)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adj',
#  '_node',
#  'add_edge',
#  'add_edges_from',
#  'add_node',
#  'add_nodes_from',
#  'add_weighted_edges_from',
#  'adj',
#  'adjacency',
#  'adjlist_inner_dict_factory',
#  'adjlist_outer_dict_factory',
#  'clear',
#  'clear_edges',
#  'copy',
#  'degree',
#  'edge_attr_dict_factory',
#  'edge_subgraph',
#  'edges',
#  'get_edge_data',
#  'graph',
#  'graph_attr_dict_factory',
#  'has_edge',
#  'has_node',
#  'is_directed',
#  'is_multigraph',
#  'name',
#  'nbunch_iter',
#  'neighbors',
# ...

# %%
paths_graph.is_directed()
# Out:
# False

# %%
paths_graph.nodes()
# Out:
# NodeView(('Calgary', 'Seattle', 'Helena', 'Portland', 'Salt Lake City', 'Montreal', 'Sault St. Marie', 'Chicago', 'Pittsburgh', 'Vancouver', 'San Francisco', 'Los Angeles', 'Las Vegas', 'Phoenix', 'El Paso', 'Winnipeg', 'Denver', 'Santa Fe', 'Duluth', 'Omaha', 'Oklahoma City', 'Houston', 'Dallas', 'Kansas City', 'New Orleans', 'Little Rock', 'Saint Louis', 'Toronto', 'Nashville', 'Atlanta', 'Miami', 'Charleston', 'Raleigh', 'Washington', 'New York', 'Boston'))

# %%
paths_graph.edges
# Out:
# EdgeView([('Calgary', 'Seattle'), ('Calgary', 'Vancouver'), ('Calgary', 'Winnipeg'), ('Calgary', 'Helena'), ('Seattle', 'Helena'), ('Seattle', 'Vancouver'), ('Seattle', 'Portland'), ('Helena', 'Salt Lake City'), ('Helena', 'Denver'), ('Helena', 'Winnipeg'), ('Helena', 'Duluth'), ('Helena', 'Omaha'), ('Portland', 'Salt Lake City'), ('Portland', 'San Francisco'), ('Salt Lake City', 'San Francisco'), ('Salt Lake City', 'Las Vegas'), ('Salt Lake City', 'Denver'), ('Montreal', 'Sault St. Marie'), ('Montreal', 'Toronto'), ('Montreal', 'New York'), ('Montreal', 'Boston'), ('Sault St. Marie', 'Winnipeg'), ('Sault St. Marie', 'Duluth'), ('Sault St. Marie', 'Toronto'), ('Chicago', 'Pittsburgh'), ('Chicago', 'Saint Louis'), ('Chicago', 'Omaha'), ('Chicago', 'Duluth'), ('Chicago', 'Toronto'), ('Pittsburgh', 'Toronto'), ('Pittsburgh', 'Saint Louis'), ('Pittsburgh', 'Washington'), ('Pittsburgh', 'New York'), ('San Francisco', 'Los Angeles'), ('Los Angeles', 'Las Vegas'), ('Los Angeles', 'Phoenix')
# ...

# %%
dir(paths_graph.edges)
# Out:
# ['__abstractmethods__',
#  '__and__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  '_abc_impl',
#  '_adjdict',
#  '_from_iterable',
#  '_graph',
#  '_hash',
#  '_nodes_nbrs',
#  'data',
#  'dataview',
#  'get',
#  'isdisjoint',
#  'items',
#  'keys',
#  'values']

# %%
nx.info(paths_graph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 36\nNumber of edges: 76\nAverage degree:   4.2222'

# %%
nx.draw(paths_graph, with_labels = True)
# missing seattle - calgary
