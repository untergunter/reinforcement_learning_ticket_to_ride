# %% [markdown]
# steps:
# 1. load map nets to network
# 2. graph conected components
# 3. qury is x in our net

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
paths = pd.read_csv(r'Railroads.csv')
paths.head()
# Out:
#          from               to  length   color
# 0     Seattle          Calgary       4    gray
# 1     Seattle           Helena       6  yellow
# 2    Portland   Salt Lake City       6    blue
# 3    Montreal  Sault St. Marie       5   black
# 4  Pittsburgh          Chicago       3  orange

# %%
paths_graph = nx.from_pandas_edgelist(paths,source='from',target='to')

# %%
type(paths_graph)
# Out:
# networkx.classes.graph.Graph

# %%
dir(paths_graph)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adj',
#  '_node',
#  'add_edge',
#  'add_edges_from',
#  'add_node',
#  'add_nodes_from',
#  'add_weighted_edges_from',
#  'adj',
#  'adjacency',
#  'adjlist_inner_dict_factory',
#  'adjlist_outer_dict_factory',
#  'clear',
#  'clear_edges',
#  'copy',
#  'degree',
#  'edge_attr_dict_factory',
#  'edge_subgraph',
#  'edges',
#  'get_edge_data',
#  'graph',
#  'graph_attr_dict_factory',
#  'has_edge',
#  'has_node',
#  'is_directed',
#  'is_multigraph',
#  'name',
#  'nbunch_iter',
#  'neighbors',
#  'node_attr_dict_factory',
#  'node_dict_factory',
#  'nodes',
#  'number_of_edges',
#  'number_of_nodes',
#  'order',
#  'remove_edge',
#  'remove_edges_from',
#  'remove_node',
#  'remove_nodes_from',
#  'size',
#  'subgraph',
#  'to_directed',
#  'to_directed_class',
#  'to_undirected',
#  'to_undirected_class',
#  'update']

# %%
paths_graph.is_directed()
# Out:
# False

# %%
paths_graph.nodes()
# Out:
# NodeView(('Seattle', 'Calgary', 'Helena', 'Portland', 'Salt Lake City', 'Montreal', 'Sault St. Marie', 'Pittsburgh', 'Chicago', 'Vancouver', 'San Francisco', 'Los Angeles', 'Las Vegas', 'Phoenix', 'El Paso', 'Winnipeg', 'Denver', 'Santa Fe', 'Duluth', 'Omaha', 'Oklahoma City', 'Houston', 'Dallas', 'Kansas City', 'New Orleans', 'Little Rock', 'Saint Louis', 'Toronto', 'Nashville', 'Atlanta', 'Miami', 'Charleston', 'Raleigh', 'Washington', 'New York', 'Boston'))

# %%
paths_graph.edges
# Out:
# EdgeView([('Seattle', 'Calgary'), ('Seattle', 'Helena'), ('Seattle', 'Vancouver'), ('Seattle', 'Portland'), ('Calgary', 'Vancouver'), ('Calgary', 'Winnipeg'), ('Calgary', 'Helena'), ('Helena', 'Salt Lake City'), ('Helena', 'Denver'), ('Helena', 'Winnipeg'), ('Helena', 'Duluth'), ('Helena', 'Omaha'), ('Portland', 'Salt Lake City'), ('Portland', 'San Francisco'), ('Salt Lake City', 'San Francisco'), ('Salt Lake City', 'Las Vegas'), ('Salt Lake City', 'Denver'), ('Montreal', 'Sault St. Marie'), ('Montreal', 'Toronto'), ('Montreal', 'New York'), ('Montreal', 'Boston'), ('Sault St. Marie', 'Winnipeg'), ('Sault St. Marie', 'Duluth'), ('Sault St. Marie', 'Toronto'), ('Pittsburgh', 'Chicago'), ('Pittsburgh', 'Toronto'), ('Pittsburgh', 'Saint Louis'), ('Pittsburgh', 'Washington'), ('Pittsburgh', 'New York'), ('Chicago', 'Saint Louis'), ('Chicago', 'Omaha'), ('Chicago', 'Duluth'), ('Chicago', 'Toronto'), ('San Francisco', 'Los Angeles'), ('Los Angeles', 'Las Vegas'), ('Los Angeles', 'Phoenix'), ('Los Angeles', 'El Paso'), ('Phoenix', 'Denver'), ('Phoenix', 'Santa Fe'), ('Phoenix', 'El Paso'), ('El Paso', 'Oklahoma City'), ('El Paso', 'Houston'), ('El Paso', 'Dallas'), ('El Paso', 'Santa Fe'), ('Winnipeg', 'Duluth'), ('Denver', 'Santa Fe'), ('Denver', 'Oklahoma City'), ('Denver', 'Kansas City'), ('Denver', 'Omaha'), ('Santa Fe', 'Oklahoma City'), ('Duluth', 'Omaha'), ('Duluth', 'Toronto'), ('Omaha', 'Kansas City'), ('Oklahoma City', 'Dallas'), ('Oklahoma City', 'Kansas City'), ('Oklahoma City', 'Little Rock'), ('Houston', 'New Orleans'), ('Houston', 'Dallas'), ('Dallas', 'Little Rock'), ('Kansas City', 'Saint Louis'), ('New Orleans', 'Little Rock'), ('New Orleans', 'Atlanta'), ('New Orleans', 'Miami'), ('Little Rock', 'Saint Louis'), ('Little Rock', 'Nashville'), ('Saint Louis', 'Nashville'), ('Nashville', 'Atlanta'), ('Nashville', 'Raleigh'), ('Atlanta', 'Miami'), ('Atlanta', 'Charleston'), ('Atlanta', 'Raleigh'), ('Miami', 'Charleston'), ('Charleston', 'Raleigh'), ('Raleigh', 'Washington'), ('Washington', 'New York'), ('New York', 'Boston')])

# %%
dir(paths_graph.edges)
# Out:
# ['__abstractmethods__',
#  '__and__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  '_abc_impl',
#  '_adjdict',
#  '_from_iterable',
#  '_graph',
#  '_hash',
#  '_nodes_nbrs',
#  'data',
#  'dataview',
#  'get',
#  'isdisjoint',
#  'items',
#  'keys',
#  'values']

# %%
nx.info(paths_graph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 36\nNumber of edges: 76\nAverage degree:   4.2222'

# %%
nx.draw(paths_graph, with_labels = True)
# missing seattle - calgary
